# %%
import os
import traceback
import pandas as pd
import geopandas as gpd
import sqlalchemy
import matplotlib.pyplot as plt
import numpy as np
import math

user='hifld_summer'
pw='hifld_summer'
name='hifld_summer'
host='moria'
port=2023
engine = sqlalchemy.create_engine(
    f'postgresql://{user}:{pw}@{host}:{port}/{name}'
    )

# %%
sql ="""
select build_id, geom, prim_occ from structures.alabama limit 500000
"""
try:
    gdf = gpd.GeoDataFrame.from_postgis(sql, con=engine,geom_col='geom') # epsq 4346

    gdf = gdf.to_crs("ESRI:102003") # USA_Contiguous_Albers_Equal_Area_Conic Projection

    area = gdf.area
    perimeter = gdf.length
    gdf["compactness"] = 1 / (perimeter.values / (2 * math.pi * ((area.values / math.pi)**.5)))

except Exception:
    print(traceback.print_exc())
# Out:
# count    5000.000000
# mean        0.839314
# std         0.060511
# min         0.370606
# 25%         0.827797
# 50%         0.860473
# 75%         0.879271
# max         0.886214
# Name: compactness, dtype: float64
