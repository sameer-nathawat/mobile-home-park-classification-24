# %%
import os
import traceback
import pandas as pd
import geopandas as gpd
import sqlalchemy
import matplotlib.pyplot as plt
import numpy as np
import math

user='hifld_summer'
pw='hifld_summer'
name='hifld_summer'
host='moria'
port=2023
engine = sqlalchemy.create_engine(
    f'postgresql://{user}:{pw}@{host}:{port}/{name}'
    )

# %%
sql ="""
select build_id, geom, prim_occ from structures.alabama limit 500000
"""
try:
    gdf = gpd.GeoDataFrame.from_postgis(sql, con=engine,geom_col='geom') # epsq 4346

    gdf = gdf.to_crs("ESRI:102003") # USA_Contiguous_Albers_Equal_Area_Conic Projection

    area = gdf.area
    perimeter = gdf.length
    gdf["compactness"] = (4 * math.pi * area.values) / (perimeter.values ** 2)

except Exception:
    print(traceback.print_exc())
# Out:
# count    50000.000000
# mean         0.690493
# std          0.109259
# min          0.063531
# 25%          0.654091
# 50%          0.728261
# 75%          0.769274
# max          0.785388
# Name: compactness, dtype: float64
